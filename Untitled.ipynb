# %%
# !pip3 install torch torchvision torchaudio

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# !cd yolov5 & pip install -r requirements.txt

# %%
import torch 
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %% [markdown]
# Load Model

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# Using cache found in C:\Users\vinit sharma/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2025-4-14 Python-3.12.4 torch-2.6.0+cpu CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %%
model
# Out:
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): DetectionModel(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
# ...

# %% [markdown]
# Make Detections with Images

# %%
img = r'C:\Users\vinit sharma\sap 1\Cars_in_traffic_in_Auckland,_New_Zealand_-_copyright-free_photo_released_to_public_domain.jpg'

# %%
results = model(img)
results.print()
# Out:
# C:\Users\vinit sharma/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# image 1/1: 3456x5184 1 person, 29 cars, 4 trucks
# Speed: 557.6ms pre-process, 228.7ms inference, 0.0ms NMS per image at shape (1, 3, 448, 640)

# %%
# %matplotlib inline 
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
results.render()

# %% [markdown]
# Real Time Detections

# %%
import cv2
import numpy as np

cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Run your model
    results = model(frame)

    # Show detection
    img = np.squeeze(results.render())
    cv2.imshow('YOLO', img)

    # Poll GUI events; q to quit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Cleanup
cap.release()
cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 11
#       8     break
#      10 # Run your model
# ---> 11 results = model(frame)
#      13 # Show detection
#      14 img = np.squeeze(results.render())
#
# File ~\anaconda3\envs\py39_env\lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\envs\py39_env\lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
# ...

# %% [markdown]
# Train from scratch

# %%
import uuid # unique identifier
import os
import time

# %%
IMAGES_PATH = os.path.join('data', 'images') #/data/images
labels = ['awake', 'drowsy']
number_imgs = 20

# %%
cap = cv2.VideoCapture(0)
# Loop through labels
for label in labels:
    print('Collecting images for {}'.format(label))
    time.sleep(5)
    
    # Loop through image range
    for img_num in range(number_imgs):
        print('Collecting images for {}, image number {}'.format(label, img_num))
        
        # Webcam feed
        ret, frame = cap.read()
        
        # Naming out image path
        imgname = os.path.join(IMAGES_PATH, label+'.'+str(uuid.uuid1())+'.jpg')
        
        # Writes out image to file 
        cv2.imwrite(imgname, frame)
        
        # Render to the screen
        cv2.imshow('Image Collection', frame)
        
        # 2 second delay between captures
        time.sleep(2)
        
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
cap.release()
cv2.destroyAllWindows()

# %%
print(os.path.join(IMAGES_PATH, labels[0]+'.'+str(uuid.uuid1())+'.jpg'))
# Out:
# data\images\awake.3cf1e54f-1911-11f0-950e-af2337ba8398.jpg

# %%
for label in labels:
    print('Collecting images for {}'.format(label))
    for img_num in range(number_imgs):
        print('Collecting images for {}, image number {}'.format(label, img_num))
        imgname = os.path.join(IMAGES_PATH, label+'.'+str(uuid.uuid1())+'.jpg')
        print(imgname)
# Out:
# ...
# data\images\awake.f8638db5-1913-11f0-84dd-af2337ba8398.jpg
# ...
# data\images\awake.f8638db6-1913-11f0-afa1-af2337ba8398.jpg
# ...
# data\images\awake.f8638db7-1913-11f0-8587-af2337ba8398.jpg
# ...
# data\images\awake.f8638db8-1913-11f0-9a0e-af2337ba8398.jpg
# ...
# data\images\awake.f8638db9-1913-11f0-b511-af2337ba8398.jpg
# ...
# data\images\awake.f8638dba-1913-11f0-9906-af2337ba8398.jpg
# ...
# data\images\awake.f8638dbb-1913-11f0-8a90-af2337ba8398.jpg
# ...
# data\images\awake.f8638dbc-1913-11f0-8e44-af2337ba8398.jpg
# ...
# data\images\awake.f8638dbd-1913-11f0-8913-af2337ba8398.jpg
# ...
# data\images\awake.f8638dbe-1913-11f0-a092-af2337ba8398.jpg
# ...
# data\images\awake.f8638dbf-1913-11f0-973e-af2337ba8398.jpg
# ...
# data\images\awake.f8638dc0-1913-11f0-8feb-af2337ba8398.jpg
# ...
# data\images\awake.f8638dc1-1913-11f0-b481-af2337ba8398.jpg
# ...
# data\images\awake.f8638dc2-1913-11f0-ada4-af2337ba8398.jpg
# ...
# data\images\awake.f8638dc3-1913-11f0-bbf1-af2337ba8398.jpg
# ...
# data\images\awake.f8638dc4-1913-11f0-98f9-af2337ba8398.jpg
# ...

# %%
# !git clone https://github.com/tzutalin/labelImg
# Out:
# fatal: destination path 'labelImg' already exists and is not an empty directory.

# %%
# !pip install pyqt5 lxml --upgrade
# !cd labelImg && pyrcc5 -o libs/resources.py resources.qrc
# Out:
# ...
#    ---------------------------------------- 0.0/6.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/6.9 MB ? eta -:--:--
#    ---- ----------------------------------- 0.8/6.9 MB 2.2 MB/s eta 0:00:03
#    ------- -------------------------------- 1.3/6.9 MB 2.4 MB/s eta 0:00:03
#    ------------ --------------------------- 2.1/6.9 MB 2.8 MB/s eta 0:00:02
#    ------------------ --------------------- 3.1/6.9 MB 3.2 MB/s eta 0:00:02
#    ---------------------- ----------------- 3.9/6.9 MB 3.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.0/6.9 MB 3.6 MB/s eta 0:00:01
#    ------------------------------------ --- 6.3/6.9 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 6.9/6.9 MB 4.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ----------- ---------------------------- 1.0/3.8 MB 5.6 MB/s eta 0:00:01
#    ------------------------ --------------- 2.4/3.8 MB 5.6 MB/s eta 0:00:01
# ...

# %%
# !cd yolov5 && python train.py --img 320 --batch 16 --epochs 500 --data dataset.yaml --weights yolov5s.pt --workers 2

# %% [markdown]
# Load Custom Model

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path= r'C:\Users\vinit sharma\Drowsiness detedction model\yolov5\runs\train\exp\weights\last.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to C:\Users\vinit sharma/.cache\torch\hub\master.zip
# YOLOv5  2025-4-14 Python-3.9.21 torch-2.6.0+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7055974 parameters, 0 gradients, 15.9 GFLOPs
# Adding AutoShape...

# %%
img = r'C:\Users\vinit sharma\Drowsiness detedction model\data\images\drowsy.f506f6d3-1910-11f0-be54-af2337ba8398.jpg'

# %%
results = model(img)

# %%
results.print()
# Out:
# image 1/1: 480x640 1 drowsy
# Speed: 53.9ms pre-process, 127.2ms inference, 10.0ms NMS per image at shape (1, 3, 480, 640)

# %%
# %matplotlib inline 
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 cap = cv2.VideoCapture(0)
#       2 while cap.isOpened():
#       3     ret, frame = cap.read()
#
# NameError: name 'cv2' is not defined
